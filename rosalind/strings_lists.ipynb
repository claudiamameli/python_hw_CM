# %% [markdown]
# # Strings and Lists
# https://rosalind.info/problems/ini3/

# %% [markdown]
# The problem gives us a string to slice two words out of it. We are also given specific index characters to splice the right words.

# %%
my_string = 'HumptyDumptysatonawallHumptyDumptyhadagreatfallAlltheKingshorsesandalltheKingsmenCouldntputHumptyDumptyinhisplaceagain.'

# %%
print(my_string[22:28], my_string[97:103])
# Out:
# Humpty Dumpty

# %% [markdown]
# Now we do it with the dataset given.

# %%
my_string = '0qKYsrtCiZ6LGd3rNJuJNbhkt63oOJQfngf0LRA5OxyuraOr46ti8yw2ZHKYI9UavzfQVfs4glJob4GztZTPkVI92KDWEhywogura6OiEL7yHuUvcA62WFhdk1SZQyaHrTiGJn5qrZGaC0lRFEuztj5zKBImXCB.'

# %%
print(my_string[40:46], my_string[95:101])
# Out:
# Oxyura wogura
