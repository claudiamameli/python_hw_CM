# %% [markdown]
# # Finding a morif in DNA
# https://rosalind.info/problems/subs/

# %% [markdown]
# ### Practice
# Given 2 strings `s` and `t`, `t` is a substring of `s`. The position of a symbol in a string is the total number of symbols found to its left, including itself (e.g., the positions of all occurrences of 'U' in "AUGCUUCAGAAAGGUCUUACG" are 2, 5, 6, 15, 17, and 18). The symbol at position `i` of `s` is denoted by `s[i]`. Similarly a substring can tbe represented as `t = s[2:5]`. <br/>
#
# t = s[j:k] --> we want all instances of j!

# %%
s = "GATATATGCATATACTT"
t = "ATAT"

# %%
counter = 0 
for i in s:
    if s[counter:counter + 4] == t:
        print(counter + 1) # this is just to match rosalind's exercise (1-numbering)
        counter += 1
    else:
        counter += 1
# Out:
# 2
# 4
# 10

# %%
for i in range(len(s)): # if i use range() I can directly add to i and don't need to use a counter
    if s[i:i + len(t)] == t: # len(t) is a more generic approach
        print(i + 1)
# Out:
# 2
# 4
# 10

# %% [markdown]
# ### Rosalind's exercise

# %%
s = "..."
t = "AACATGCAA"

# %%
for i in range(len(s)):
    if s[i:i + len(t)] == t: 
        print(i + 1)
# Out:
# 65
# 107
# 114
# 121
# 128
# 165
# 180
# 187
# 195
# 210
# 217
# 247
# 285
# 325
# 342
# 349
# 366
# 374
# 381
# 402
# 418
# 472
# 479
# 487
# 521
# 528
# 535
# 557
# 576
# 583
# 590
# 613
# 620
# 652
# 677
# 714
# 740
# 747
# 763
# 771
# 778
# 820
# 852
