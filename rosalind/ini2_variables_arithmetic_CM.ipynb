# %% [markdown]
# # Variables and Some Arithmetic
# https://rosalind.info/problems/ini2/

# %% [markdown]
# The problem aks of us do create a formula which calculates the hypothenuse of a triangle. We are given 2 integers for the sides.

# %%
a = 3

# %%
b = 5

# %%
a**2 + b**2
# Out:
# 34

# %% [markdown]
# Now we do it with the given dataset

# %%
a = 953

# %%
b = 914

# %%
a**2 + b**2
# Out:
# 1743605
