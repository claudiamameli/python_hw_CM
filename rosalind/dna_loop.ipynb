# %% [markdown]
# # Counting DNA Nucleotides - Using loops
# The same exercise found at https://rosalind.info/problems/dna/ is solved with a different approach. This time we use a loop.

# %%
dna = "..."

count = {}

for nucl in dna:
    count[nucl] = dna.count(nucl)
print(count)
# Out:
# {'C': 237, 'T': 227, 'G': 209, 'A': 202}
