# %% [markdown]
# # Counting DNA Nucleotides - The dictionary method
# The same exercise found at https://rosalind.info/problems/dna/ is solved with a different approach. This time we create a dictionary object with the count of the nucleotides.

# %%
dna_dict = {}

# %%
dna = "..."

# %%
dna_dict.update({'A': dna.count("A")})
dna_dict.update({'C': dna.count("C")})
dna_dict.update({'G': dna.count("G")})
dna_dict.update({'T': dna.count("T")})

# %%
print(dna_dict)
# Out:
# {'A': 202, 'C': 237, 'G': 209, 'T': 227}

# %% [markdown]
# Alternitively, we can also directly assign all keys and values together as our dictionary is empty to begin with.

# %%
dna_dict_ver2 = {'A': dna.count("A"),
                 'C': dna.count("C"), 
                 'G': dna.count("G"),
                 'T': dna.count("T")}

# %%
print(dna_dict_ver2)
# Out:
# {'A': 202, 'C': 237, 'G': 209, 'T': 227}
