# %% [markdown]
# # Calculating Expected Offspring
# https://rosalind.info/problems/iev/

# %% [markdown]
# ### Practice

# %%
(2 * 1) + (2 * 3/4)
# Out:
# 3.5

# %%
# probabilities
AAAA1 = 1 
AAAa2 = 1
AAaa3 = 1
AaAa4 = 3/4
Aaaa5 = 1/2 
aaaa6 = 0

# %%
n1 = 2 * 18043
n2 = 2 * 19690
n3 = 2 * 19111
n4 = 2 * 17577
n5 = 2 * 19548

p = (AAAA1 * n1) + (AAAa2 * n2) + (AAaa3 * n3) + (AaAa4 * n4) + (Aaaa5 * n5)
print(p)
# Out:
# 159601.5

# %% [markdown]
# This is the correct idea but it is not very pythonic. Perhaps I can read the file and create a variable and a probability variable to loop over?

# %%
file_path = 'rosalind_iev_test.txt'
with open (file_path, 'r') as infile:
    s = (infile.readline())
    s = s.rstrip()
    couples = s.split(" ")
    print(couples)
# Out:
# ['1', '0', '0', '1', '0', '1']

# %%
probs = [1, 1, 1, 0.75, 0.5, 0]

# %%
result = 0
# zip allows for iteration in multiple variables at the same time!
for x, y in zip(couples, probs): 
    result += (int(x)*2 * y)
print(result)
# Out:
# 3.5

# %% [markdown]
# ### Rosalind's problem

# %%
file_path = 'rosalind_iev.txt'
with open (file_path, 'r') as infile:
    s = (infile.readline())
    s = s.rstrip()
    couples = s.split(" ")
    print(couples)
# Out:
# ['18043', '19690', '19111', '17577', '19548', '18538']

# %%
probs = [1, 1, 1, 0.75, 0.5, 0]
result = 0
for x, y in zip(couples, probs):
    result += (int(x)*2 * y)
print(result)
# Out:
# 159601.5
