# %% [markdown]
# ## Strings and Functions

# %%
b = 4

# %%
type(b)
# Out:
# int

# %%
a = 'ciao'

# %%
print(type(a)) #this also prints what we are doing
# Out:
# <class 'str'>

# %%
c = 4.5

# %%
print(type(c))
# Out:
# <class 'float'>

# %%
print(type(5-3))
# Out:
# <class 'int'>

# %%
print(type('hello' - 'h')) #making operations on strings is not possible in this way
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(type('hello' - 'h')) #making operations on strings is not possible in this way
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
len(a) #how long is the string a
# Out:
# 4

# %%
some_long_string = 'the brown fox jumps jumps over the lazy dog\n'

# %%
len(some_long_string) #line breaks will also have an extra character at the end
# Out:
# 44

# %%
some_long_string[0:4]
# Out:
# 'the '

# %%
some_long_string[0:44]
# Out:
# 'the brown fox jumps jumps over the lazy dog\n'

# %%
str(1992)
# Out:
# '1992'

# %%
len(str(1992))
# Out:
# 4

# %%
b = 1992

# %%
len(str(b))
# Out:
# 4

# %%
some_number = '75'

# %%
1 + some_number
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 1 + some_number
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
1 + int(some_number)
# Out:
# 76

# %%
some_number = '75.8'

# %%
1 + float(some_number)
# Out:
# 76.8

# %%
int(len(str(10/3)))
# Out:
# 18

# %%
type(int(len(str(10/3))))
# Out:
# int

# %% [markdown]
# ## Functions

# %%
"test test".upper()
# Out:
# 'TEST TEST'

# %%
test = print('bla bla')
# Out:
# bla bla

# %%
test

# %%
type(test) #We can see that what we wrote has not successfully created a function
# Out:
# NoneType
