# %% [markdown]
# # Experimenting with python

# %%
print("Hello World! :)")
# Out:
# Hello World! :)

# %% [markdown]
# ## Math Operators

# %% [markdown]
# ### Divisions
#
# "%" will print out the remaining number out of a division, so for example we have 10 devided by 3 nd the resulting number will be 1 --> modulo

# %%
10 % 3
# Out:
# 1

# %%
10 // 3
# Out:
# 3

# %%
10 / 3
# Out:
# 3.3333333333333335

# %% [markdown]
# ### Multiplications

# %%
2 * 100
# Out:
# 200

# %%
2 ** 100 #to the power of
# Out:
# 1267650600228229401496703205376

# %% [markdown]
# ## Words

# %%
"hello"+"world" #concatenating (for words)
# Out:
# 'helloworld'

# %%
"hello " * 8 #multiplies strings
# Out:
# 'hello hello hello hello hello hello hello hello '

# %%
8 * " Hello"
# Out:
# ' Hello Hello Hello Hello Hello Hello Hello Hello'

# %% [markdown]
# ### Expression comprehension
# 1. (12*2 + 5*2) / 2
# 2. (12**2 + 5**2)**0.5
# 3. 12^2 + 5^2)^05
#
# n2 is the correct answer. This is why ^ does somthing different than making the power of something.

# %% [markdown]
# ### Assigning values to variables

# %%
x = 3

# %%
2 + x
# Out:
# 5

# %%
y = 10 / 7

# %%
y
# Out:
# 1.4285714285714286

# %%
x
# Out:
# 3

# %%
print(x, y)
# Out:
# 3 1.4285714285714286

# %%
x = x + y

# %%
x
# Out:
# 4.428571428571429

# %% [markdown]
# ### String functions

# %%
s = "the quick brown fox jumps over the lazy dog"

# %%
s
# Out:
# 'the quick brown fox jumps over the lazy dog'

# %%
print(s)
# Out:
# the quick brown fox jumps over the lazy dog

# %%
s.upper()
# Out:
# 'THE QUICK BROWN FOX JUMPS OVER THE LAZY DOG'

# %%
s.lower()
# Out:
# 'the quick brown fox jumps over the lazy dog'

# %%
s.title()
# Out:
# 'The Quick Brown Fox Jumps Over The Lazy Dog'

# %%
s.capitalize()
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
s
# Out:
# 'the quick brown fox jumps over the lazy dog'

# %%
s = s.capitalize()

# %%
s
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
s = s.lower()

# %%
s
# Out:
# 'the quick brown fox jumps over the lazy dog'

# %%
s.count("the") #case sensitive
# Out:
# 2

# %%
s = s.capitalize()

# %%
s
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
s.lower().count("the")
# Out:
# 2

# %%
s.split() #creates different subscripts --> list
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
s.split("o") #splits at specific character
# Out:
# ['The quick br', 'wn f', 'x jumps ', 'ver the lazy d', 'g']

# %%
test = "test test test test"

# %%
test.replace("e", "a")
# Out:
# 'tast tast tast tast'
