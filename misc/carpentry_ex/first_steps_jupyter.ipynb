# %%
print("Hello")
# Out:
# Hello

# %%
7*3
# Out:
# 21

# %%
2+1
# Out:
# 3

# %%
7*3
2+1
# Out:
# 3

# %% [markdown]
# 1. Get funding.
# 2. Do work.
#     * Design experiment.
#     * Collect data.
#     * Analyze.
# 3. Write up.
# 4. Publish.

# %% [markdown]
# $\sum_{i=1}^{N} 2^{-i} \approx 1$
